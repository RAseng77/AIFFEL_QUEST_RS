# %% [markdown]
# <a href="https://colab.research.google.com/github/RAseng77/AIFFEL_QUEST_RS/blob/master/GoingDeeper/GD01/GoingDeeper01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import cv2
import PIL

print(torch.__version__)
print(np.__version__)
print(cv2.__version__)
print(PIL.__version__)
# Out:
# 2.7.1+cu118
# 2.2.6
# 4.13.0
# 11.2.1

# %%
import os
import shutil
import scipy.io as sio
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import cv2
import torch.nn.functional as F

import xml.etree.ElementTree as ET
from PIL import Image, ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# 원본 데이터 경로 (압축 해제 후 폴더)
images_dir = os.path.join(os.getenv("HOME"), 'work/class_activation_map/Images')   # 이미지들이 위치한 폴더
mat_dir = os.path.join(os.getenv("HOME"), 'work/class_activation_map')   # 프로젝트 루트 디렉토리

# .mat 파일 경로 (train_list.mat와 test_list.mat가 각각 같은 구조라고 가정)
train_mat_path = os.path.join(mat_dir, 'train_list.mat')
test_mat_path = os.path.join(mat_dir, 'test_list.mat')

# .mat 파일 로드
train_mat = sio.loadmat(train_mat_path)
test_mat = sio.loadmat(test_mat_path)

# train_mat와 test_mat 내부에 'file_list'와 'labels' 등이 있음
train_file_list = train_mat['file_list']
train_labels = train_mat['labels'].squeeze()  # (N,)
test_file_list = test_mat['file_list']
test_labels = test_mat['labels'].squeeze()

# 최종적으로 ImageFolder 구조로 재구성할 대상 폴더 생성 (예: stanford_dogs/train, stanford_dogs/test)
base_dir = 'stanford_dogs'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

def process_mat_file(file_list_array, split_dir):
    """
    .mat 파일에서 로드한 file_list_array를 사용해,
    split_dir(예: train 혹은 test)에 클래스별 폴더를 생성하고 이미지를 복사합니다.
    """
    num_files = file_list_array.shape[0]
    for idx in range(num_files):
        # file_list_array[idx]는 보통 array([<파일경로>]) 형태입니다.
        # 따라서, array([<파일경로>]).item()을 사용하면 실제 문자열을 얻을 수 있습니다.
        file_path = file_list_array[idx][0].item()

        # 혹시 bytes 타입이면 문자열로 디코딩
        if isinstance(file_path, bytes):
            file_path = file_path.decode('utf-8')

        # 파일 경로 예시: 'n02116738-African_hunting_dog/n02116738_2988.jpg'
        # 클래스 이름은 파일 경로의 최상위 폴더명 (예: 'n02116738-African_hunting_dog')
        class_folder = file_path.split('/')[0]

        # 대상 클래스 폴더 생성
        dest_folder = os.path.join(split_dir, class_folder)
        os.makedirs(dest_folder, exist_ok=True)

        # 원본 이미지 경로: Images 폴더 아래에 file_path 위치
        src_path = os.path.join(images_dir, file_path)
        # 대상 이미지 경로: dest_folder 아래에 원본 파일명 그대로 복사
        dest_path = os.path.join(dest_folder, os.path.basename(file_path))

        # 파일 존재 여부 확인 후 복사
        if os.path.exists(src_path):
            shutil.copy(src_path, dest_path)
        else:
            print(f"File not found: {src_path}")

print("Processing train set...")
process_mat_file(train_file_list, train_dir)
print("Processing test set...")
process_mat_file(test_file_list, test_dir)

print("Dataset reorganization complete.")
# Out:
# Processing train set...
# Processing test set...
# Dataset reorganization complete.

# %%
class StanfordDogsDatasetWithBBox(datasets.ImageFolder):
    def __init__(self, root, annotation_root, transform=None):
        super().__init__(root, transform=transform)
        self.annotation_root = annotation_root  # 예: '/content/Annotation'
        self.new_size = (224, 224)

    def __getitem__(self, index):
        image, label = super().__getitem__(index)
        path, _ = self.samples[index]

        rel_path = os.path.relpath(path, self.root)
        annot_filename = os.path.splitext(os.path.basename(rel_path))[0]
        annot_folder = os.path.dirname(rel_path)
        annot_path = os.path.join(self.annotation_root, annot_folder, annot_filename)

        # bbox 기본값 (예: [ymin, xmin, ymax, xmax])
        bbox = [0.0, 0.0, 0.0, 0.0]

        if os.path.exists(annot_path):
            try:
                # 확장자가 없지만 XML 형식의 파일이라고 가정하고 파싱
                tree = ET.parse(annot_path)
                root_xml = tree.getroot()
                # 첫 번째 object 태그에서 bndbox 정보를 읽음
                obj = root_xml.find('object')
                if obj is not None:
                    bndbox = obj.find('bndbox')
                    if bndbox is not None:
                        xmin = float(bndbox.find('xmin').text)
                        ymin = float(bndbox.find('ymin').text)
                        xmax = float(bndbox.find('xmax').text)
                        ymax = float(bndbox.find('ymax').text)
                        # XML 내 <size> 태그에서 원본 이미지 크기 획득
                        size = root_xml.find('size')
                        w = float(size.find('width').text)
                        h = float(size.find('height').text)
                        new_h, new_w = self.new_size
                        # bbox 좌표 순서: [ymin, xmin, ymax, xmax]
                        bbox = [xmin * (new_w / w), ymin * (new_h / h),
                                xmax * (new_w / w), ymax * (new_h / h)]
                    else:
                        print(f"bndbox 태그를 찾을 수 없습니다: {annot_path}")
                else:
                    print(f"object 태그를 찾을 수 없습니다: {annot_path}")
            except Exception as e:
                print(f"Error parsing {annot_path}: {e}")
        else:
            print(f"Annotation file not found: {annot_path}")

        return image, label, bbox

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# 데이터셋 경로 (재구성한 ImageFolder 형식)
train_dir = os.path.join('stanford_dogs', 'train')
test_dir = os.path.join('stanford_dogs', 'test')
# Annotation 폴더 경로 (예: '/root/Annotation')
annotation_dir = os.path.join(os.getenv("HOME"), 'work/class_activation_map/Annotation')

# 커스텀 데이터셋 생성: image, label, bbox 반환
train_dataset = StanfordDogsDatasetWithBBox(root=train_dir, annotation_root=annotation_dir, transform=transform)
valid_dataset = StanfordDogsDatasetWithBBox(root=test_dir, annotation_root=annotation_dir, transform=transform)

batch_size = 12
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

num_classes = len(train_dataset.classes)
print(f"Number of classes: {num_classes}")
print(f"Train samples: {len(train_dataset)}")
print(f"Test samples: {len(valid_dataset)}")
# Out:
# Number of classes: 120
# Train samples: 12000
# Test samples: 8580

# %%
def visualize(sample):
    img_tensor, label, bbox = sample

    # 인덱스와 클래스 정보
    print("Label index:", label)
    print("Class name:", train_dataset.classes[label])

    # 정규화 복원 전처리 시 사용한 평균과 표준편차
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])

    # tensor의 shape: (C, H, W) -> (H, W, C)
    img_np = img_tensor.permute(1, 2, 0).numpy()
    img_np = std * img_np + mean
    img_np = np.clip(img_np, 0 , 1)

    plt.figure(figsize=(6, 6))
    plt.imshow(img_np)
    plt.title(f"Class: {train_dataset.classes[label]}")
    plt.axis('off')
    plt.show()

# %%
# 임의의 한 샘플 선택 (여기서는 첫 번째 샘플을 사용)
train_sample = train_dataset[15]

visualize(train_sample)
# Out:
# Label index: 0
# Class name: n02085620-Chihuahua

# %%
# Annotation 폴더에서 데이터를 골라보세요
annotation_path = os.path.join(os.getenv("HOME"), 'work/class_activation_map/Annotation/n02085620-Chihuahua/n02085620_10074')


# XML 파일 파싱
tree = ET.parse(annotation_path)
root = tree.getroot()

for elem in root.iter():
    print(f"{elem.tag}: {elem.text}")
# Out:
# annotation:
#
# folder: 02085620
# filename: n02085620_10074
# source:
#
# database: ImageNet database
# size:
#
# width: 333
# height: 500
# depth: 3
# segment: 0
# object:
#
# name: Chihuahua
# pose: Unspecified
# truncated: 0
# difficult: 0
# bndbox:
#
# xmin: 25
# ymin: 10
# xmax: 276
# ymax: 498

# %%
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(train_dataset.classes))
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs=2):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        print(f"\nEpoch {epoch+1}/{num_epochs} 시작")
        for batch_idx, (images, labels, _) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (preds == labels).sum().item()
            if (batch_idx + 1) % 50 == 0:
                print(f"  Step {batch_idx+1} - Loss: {loss.item():.4f}")

        train_loss = running_loss / (batch_idx + 1)
        train_acc = correct / total
        print(f"Train - Loss: {train_loss:.4f}, Accuracy: {train_acc*100:.2f}%")

        # 검증 단계
        model.eval()
        running_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels, _ in valid_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (preds == labels).sum().item()
        test_loss = running_loss / len(valid_loader)
        test_acc = correct / total
        print(f"Validation - Loss: {test_loss:.4f}, Accuracy: {test_acc*100:.2f}%")

# %%
# %%time

train_model(model, train_loader, valid_loader, criterion, optimizer, num_epochs=20)
# Out:
# Epoch 1/20 시작
#   Step 50 - Loss: 1.4377
#   Step 100 - Loss: 2.2936
#   Step 150 - Loss: 1.5172
#   Step 200 - Loss: 2.2675
#   Step 250 - Loss: 1.7078
#   Step 300 - Loss: 1.5810
#   Step 350 - Loss: 1.4343
#   Step 400 - Loss: 2.2368
#   Step 450 - Loss: 1.4016
#   Step 500 - Loss: 1.6634
#   Step 550 - Loss: 2.1996
#   Step 600 - Loss: 1.6472
#   Step 650 - Loss: 1.4710
#   Step 700 - Loss: 1.5291
#   Step 750 - Loss: 1.3418
#   Step 800 - Loss: 2.8047
#   Step 850 - Loss: 0.7301
#   Step 900 - Loss: 1.9499
#   Step 950 - Loss: 1.5500
#   Step 1000 - Loss: 1.1452
# Train - Loss: 1.7765, Accuracy: 49.28%
# Validation - Loss: 1.9625, Accuracy: 46.92%
#
# Epoch 2/20 시작
#   Step 50 - Loss: 0.6989
#   Step 100 - Loss: 1.6095
#   Step 150 - Loss: 1.5171
#   Step 200 - Loss: 1.1734
#   Step 250 - Loss: 0.8455
#   Step 300 - Loss: 1.1501
#   Step 350 - Loss: 1.2794
#   Step 400 - Loss: 1.7399
#   Step 450 - Loss: 1.9051
#   Step 500 - Loss: 1.7985
#   Step 550 - Loss: 1.3633
#   Step 600 - Loss: 1.6409
#   Step 650 - Loss: 1.8815
#   Step 700 - Loss: 1.3245
#   Step 750 - Loss: 1.0692
#   Step 800 - Loss: 1.3066
#   Step 850 - Loss: 2.4328
#   Step 900 - Loss: 0.9378
#   Step 950 - Loss: 1.6829
#   Step 1000 - Loss: 1.7224
# Train - Loss: 1.4070, Accuracy: 57.93%
# Validation - Loss: 2.2191, Accuracy: 42.74%
#
# Epoch 3/20 시작
#   Step 50 - Loss: 0.9697
#   Step 100 - Loss: 0.7103
#   Step 150 - Loss: 1.1584
#   Step 200 - Loss: 0.8755
#   Step 250 - Loss: 1.2459
#   Step 300 - Loss: 1.2402
#   Step 350 - Loss: 1.4510
#   Step 400 - Loss: 1.0895
#   Step 450 - Loss: 1.2845
#   Step 500 - Loss: 1.7088
#   Step 550 - Loss: 1.4768
#   Step 600 - Loss: 1.6420
#   Step 650 - Loss: 1.0987
#   Step 700 - Loss: 1.1352
#   Step 750 - Loss: 1.1337
#   Step 800 - Loss: 2.0661
#   Step 850 - Loss: 0.7391
#   Step 900 - Loss: 0.6797
#   Step 950 - Loss: 1.5991
#   Step 1000 - Loss: 1.3396
# Train - Loss: 1.1321, Accuracy: 65.26%
# Validation - Loss: 2.0361, Accuracy: 47.80%
#
# Epoch 4/20 시작
#   Step 50 - Loss: 1.1944
#   Step 100 - Loss: 0.8750
#   Step 150 - Loss: 1.6744
#   Step 200 - Loss: 1.1445
#   Step 250 - Loss: 0.6568
#   Step 300 - Loss: 1.0793
#   Step 350 - Loss: 1.1518
#   Step 400 - Loss: 1.4240
#   Step 450 - Loss: 0.2697
#   Step 500 - Loss: 0.2777
#   Step 550 - Loss: 1.3598
#   Step 600 - Loss: 0.8256
#   Step 650 - Loss: 1.1726
#   Step 700 - Loss: 0.7016
#   Step 750 - Loss: 1.1545
#   Step 800 - Loss: 0.7645
#   Step 850 - Loss: 1.0990
#   Step 900 - Loss: 0.8582
#   Step 950 - Loss: 1.2816
#   Step 1000 - Loss: 1.0950
# Train - Loss: 0.9178, Accuracy: 71.63%
# Validation - Loss: 2.1100, Accuracy: 49.78%
#
# Epoch 5/20 시작
#   Step 50 - Loss: 0.4372
#   Step 100 - Loss: 0.2280
#   Step 150 - Loss: 1.4547
#   Step 200 - Loss: 0.4504
#   Step 250 - Loss: 0.6447
#   Step 300 - Loss: 0.6707
#   Step 350 - Loss: 0.2615
#   Step 400 - Loss: 0.3030
#   Step 450 - Loss: 0.5644
#   Step 500 - Loss: 0.6379
#   Step 550 - Loss: 0.5140
#   Step 600 - Loss: 1.0819
#   Step 650 - Loss: 0.7973
#   Step 700 - Loss: 0.6538
#   Step 750 - Loss: 0.5176
#   Step 800 - Loss: 1.0327
#   Step 850 - Loss: 0.4572
#   Step 900 - Loss: 0.7394
#   Step 950 - Loss: 0.6570
#   Step 1000 - Loss: 0.7554
# Train - Loss: 0.7089, Accuracy: 77.86%
# Validation - Loss: 2.0973, Accuracy: 50.27%
#
# Epoch 6/20 시작
#   Step 50 - Loss: 0.4517
#   Step 100 - Loss: 1.2069
#   Step 150 - Loss: 0.3597
#   Step 200 - Loss: 0.4751
#   Step 250 - Loss: 0.6566
#   Step 300 - Loss: 0.6466
#   Step 350 - Loss: 0.5913
#   Step 400 - Loss: 0.3918
#   Step 450 - Loss: 0.3589
#   Step 500 - Loss: 0.1010
#   Step 550 - Loss: 0.2767
#   Step 600 - Loss: 0.1152
#   Step 650 - Loss: 0.3068
#   Step 700 - Loss: 0.2959
#   Step 750 - Loss: 0.7142
#   Step 800 - Loss: 0.6392
#   Step 850 - Loss: 0.6858
#   Step 900 - Loss: 1.3124
#   Step 950 - Loss: 0.7733
#   Step 1000 - Loss: 0.9438
# Train - Loss: 0.5441, Accuracy: 82.79%
# Validation - Loss: 2.0404, Accuracy: 53.29%
#
# Epoch 7/20 시작
#   Step 50 - Loss: 0.5114
#   Step 100 - Loss: 0.2620
#   Step 150 - Loss: 0.3997
#   Step 200 - Loss: 0.4268
#   Step 250 - Loss: 0.6961
#   Step 300 - Loss: 0.4203
#   Step 350 - Loss: 0.1940
#   Step 400 - Loss: 0.6011
#   Step 450 - Loss: 0.2793
#   Step 500 - Loss: 0.3377
#   Step 550 - Loss: 0.6206
#   Step 600 - Loss: 0.0845
#   Step 650 - Loss: 0.9869
#   Step 700 - Loss: 0.1209
#   Step 750 - Loss: 0.5434
#   Step 800 - Loss: 0.9082
#   Step 850 - Loss: 0.8501
#   Step 900 - Loss: 0.2061
#   Step 950 - Loss: 0.3085
#   Step 1000 - Loss: 0.3899
# Train - Loss: 0.4811, Accuracy: 84.56%
# Validation - Loss: 2.1463, Accuracy: 53.86%
#
# Epoch 8/20 시작
#   Step 50 - Loss: 0.4337
#   Step 100 - Loss: 0.4895
#   Step 150 - Loss: 0.1467
#   Step 200 - Loss: 0.6778
#   Step 250 - Loss: 0.2174
#   Step 300 - Loss: 0.1661
#   Step 350 - Loss: 0.9459
#   Step 400 - Loss: 0.1276
#   Step 450 - Loss: 0.2103
#   Step 500 - Loss: 0.3889
#   Step 550 - Loss: 0.2720
#   Step 600 - Loss: 0.5071
#   Step 650 - Loss: 0.2458
#   Step 700 - Loss: 0.2753
#   Step 750 - Loss: 0.7850
#   Step 800 - Loss: 0.7230
#   Step 850 - Loss: 0.1312
#   Step 900 - Loss: 0.1374
#   Step 950 - Loss: 0.4775
#   Step 1000 - Loss: 0.3091
# Train - Loss: 0.3656, Accuracy: 88.12%
# Validation - Loss: 2.0728, Accuracy: 53.32%
#
# Epoch 9/20 시작
#   Step 50 - Loss: 0.1385
#   Step 100 - Loss: 0.0947
#   Step 150 - Loss: 0.2360
#   Step 200 - Loss: 0.2970
#   Step 250 - Loss: 0.0568
#   Step 300 - Loss: 0.0891
#   Step 350 - Loss: 0.1704
#   Step 400 - Loss: 0.1825
#   Step 450 - Loss: 0.6781
#   Step 500 - Loss: 0.2960
#   Step 550 - Loss: 0.4709
#   Step 600 - Loss: 0.2128
#   Step 650 - Loss: 0.5158
#   Step 700 - Loss: 0.2927
#   Step 750 - Loss: 0.3258
#   Step 800 - Loss: 0.1231
#   Step 850 - Loss: 0.3203
#   Step 900 - Loss: 0.8437
#   Step 950 - Loss: 0.3796
#   Step 1000 - Loss: 0.4109
# Train - Loss: 0.2672, Accuracy: 91.70%
# Validation - Loss: 2.2259, Accuracy: 52.53%
#
# Epoch 10/20 시작
#   Step 50 - Loss: 0.7871
#   Step 100 - Loss: 0.1297
#   Step 150 - Loss: 0.1845
#   Step 200 - Loss: 0.2408
#   Step 250 - Loss: 0.0461
#   Step 300 - Loss: 0.1307
#   Step 350 - Loss: 0.9443
#   Step 400 - Loss: 0.5019
#   Step 450 - Loss: 0.0610
#   Step 500 - Loss: 0.0218
#   Step 550 - Loss: 0.5873
#   Step 600 - Loss: 0.4181
#   Step 650 - Loss: 0.2534
#   Step 700 - Loss: 0.7668
#   Step 750 - Loss: 0.2159
#   Step 800 - Loss: 1.0295
#   Step 850 - Loss: 0.2099
#   Step 900 - Loss: 0.1889
#   Step 950 - Loss: 0.0955
#   Step 1000 - Loss: 0.0706
# Train - Loss: 0.2151, Accuracy: 93.27%
# Validation - Loss: 2.2482, Accuracy: 53.21%
#
# Epoch 11/20 시작
#   Step 50 - Loss: 0.0415
#   Step 100 - Loss: 0.0571
#   Step 150 - Loss: 0.0800
#   Step 200 - Loss: 0.1133
#   Step 250 - Loss: 0.1140
#   Step 300 - Loss: 0.3892
#   Step 350 - Loss: 0.2777
#   Step 400 - Loss: 0.6159
#   Step 450 - Loss: 0.4627
#   Step 500 - Loss: 0.1883
#   Step 550 - Loss: 0.7360
#   Step 600 - Loss: 0.1127
#   Step 650 - Loss: 0.1494
#   Step 700 - Loss: 0.0786
#   Step 750 - Loss: 0.0444
#   Step 800 - Loss: 0.1130
#   Step 850 - Loss: 0.0834
#   Step 900 - Loss: 0.0167
#   Step 950 - Loss: 0.1047
#   Step 1000 - Loss: 0.3864
# Train - Loss: 0.1615, Accuracy: 95.20%
# Validation - Loss: 2.1080, Accuracy: 57.09%
#
# Epoch 12/20 시작
#   Step 50 - Loss: 0.0343
#   Step 100 - Loss: 0.0398
#   Step 150 - Loss: 0.1059
#   Step 200 - Loss: 0.0811
#   Step 250 - Loss: 0.1060
#   Step 300 - Loss: 0.0096
#   Step 350 - Loss: 0.2370
#   Step 400 - Loss: 0.1491
#   Step 450 - Loss: 0.0611
#   Step 500 - Loss: 0.0412
#   Step 550 - Loss: 0.0852
#   Step 600 - Loss: 0.0916
#   Step 650 - Loss: 0.0898
#   Step 700 - Loss: 0.0804
#   Step 750 - Loss: 0.0065
#   Step 800 - Loss: 0.1358
#   Step 850 - Loss: 0.1473
#   Step 900 - Loss: 0.3702
#   Step 950 - Loss: 0.1141
#   Step 1000 - Loss: 0.1451
# Train - Loss: 0.1269, Accuracy: 96.29%
# Validation - Loss: 1.9729, Accuracy: 58.59%
#
# Epoch 13/20 시작
#   Step 50 - Loss: 0.0116
#   Step 100 - Loss: 0.0714
#   Step 150 - Loss: 0.0078
#   Step 200 - Loss: 0.0087
#   Step 250 - Loss: 0.0119
#   Step 300 - Loss: 0.0143
#   Step 350 - Loss: 0.0280
#   Step 400 - Loss: 0.0149
#   Step 450 - Loss: 0.0190
#   Step 500 - Loss: 0.0660
#   Step 550 - Loss: 0.0930
#   Step 600 - Loss: 0.0997
#   Step 650 - Loss: 0.0170
#   Step 700 - Loss: 0.0567
#   Step 750 - Loss: 0.0278
#   Step 800 - Loss: 0.0427
#   Step 850 - Loss: 0.0187
#   Step 900 - Loss: 0.0173
#   Step 950 - Loss: 0.2198
#   Step 1000 - Loss: 0.2065
# Train - Loss: 0.0829, Accuracy: 97.72%
# Validation - Loss: 2.0998, Accuracy: 58.04%
#
# Epoch 14/20 시작
#   Step 50 - Loss: 0.0598
#   Step 100 - Loss: 0.1921
#   Step 150 - Loss: 0.0553
#   Step 200 - Loss: 0.0045
#   Step 250 - Loss: 0.0072
#   Step 300 - Loss: 0.0364
#   Step 350 - Loss: 0.0290
#   Step 400 - Loss: 0.0166
#   Step 450 - Loss: 0.0054
#   Step 500 - Loss: 0.0031
#   Step 550 - Loss: 0.0939
#   Step 600 - Loss: 0.0198
#   Step 650 - Loss: 0.2168
#   Step 700 - Loss: 0.0108
#   Step 750 - Loss: 0.0072
#   Step 800 - Loss: 0.0640
#   Step 850 - Loss: 0.0321
#   Step 900 - Loss: 0.5541
#   Step 950 - Loss: 0.0525
#   Step 1000 - Loss: 0.3142
# Train - Loss: 0.0650, Accuracy: 98.19%
# Validation - Loss: 2.1422, Accuracy: 57.37%
#
# Epoch 15/20 시작
#   Step 50 - Loss: 0.4956
#   Step 100 - Loss: 0.0118
#   Step 150 - Loss: 0.0996
#   Step 200 - Loss: 0.0108
#   Step 250 - Loss: 0.0314
#   Step 300 - Loss: 0.0401
#   Step 350 - Loss: 0.0711
#   Step 400 - Loss: 0.0107
#   Step 450 - Loss: 0.0150
#   Step 500 - Loss: 0.0129
#   Step 550 - Loss: 0.0048
#   Step 600 - Loss: 0.0260
#   Step 650 - Loss: 0.0184
#   Step 700 - Loss: 0.0431
#   Step 750 - Loss: 0.0040
#   Step 800 - Loss: 0.2444
#   Step 850 - Loss: 0.0289
#   Step 900 - Loss: 0.0082
#   Step 950 - Loss: 0.0163
#   Step 1000 - Loss: 0.0758
# Train - Loss: 0.0700, Accuracy: 98.01%
# Validation - Loss: 1.9732, Accuracy: 60.02%
#
# Epoch 16/20 시작
#   Step 50 - Loss: 0.0176
#   Step 100 - Loss: 0.0123
#   Step 150 - Loss: 0.0371
#   Step 200 - Loss: 0.0167
#   Step 250 - Loss: 0.0709
#   Step 300 - Loss: 0.0255
#   Step 350 - Loss: 0.1764
#   Step 400 - Loss: 0.0121
#   Step 450 - Loss: 0.1984
#   Step 500 - Loss: 0.0148
#   Step 550 - Loss: 0.0432
#   Step 600 - Loss: 0.0082
#   Step 650 - Loss: 0.0201
#   Step 700 - Loss: 0.0092
#   Step 750 - Loss: 0.0570
#   Step 800 - Loss: 0.0737
#   Step 850 - Loss: 0.0315
#   Step 900 - Loss: 0.0046
#   Step 950 - Loss: 0.0136
#   Step 1000 - Loss: 0.0435
# Train - Loss: 0.0616, Accuracy: 98.27%
# Validation - Loss: 2.0768, Accuracy: 59.10%
#
# Epoch 17/20 시작
#   Step 50 - Loss: 0.0058
#   Step 100 - Loss: 0.0777
#   Step 150 - Loss: 0.0114
#   Step 200 - Loss: 0.0810
#   Step 250 - Loss: 0.0214
#   Step 300 - Loss: 0.0137
#   Step 350 - Loss: 0.0698
#   Step 400 - Loss: 0.0582
#   Step 450 - Loss: 0.0117
#   Step 500 - Loss: 0.0006
#   Step 550 - Loss: 0.0596
#   Step 600 - Loss: 0.0054
#   Step 650 - Loss: 0.0027
#   Step 700 - Loss: 0.0493
#   Step 750 - Loss: 0.0692
#   Step 800 - Loss: 0.0026
#   Step 850 - Loss: 0.4358
#   Step 900 - Loss: 0.0030
#   Step 950 - Loss: 0.0177
#   Step 1000 - Loss: 0.0062
# Train - Loss: 0.0401, Accuracy: 98.96%
# Validation - Loss: 2.0692, Accuracy: 59.56%
#
# Epoch 18/20 시작
#   Step 50 - Loss: 0.0090
#   Step 100 - Loss: 0.0229
#   Step 150 - Loss: 0.0029
#   Step 200 - Loss: 0.0289
#   Step 250 - Loss: 0.0033
#   Step 300 - Loss: 0.0006
#   Step 350 - Loss: 0.0024
#   Step 400 - Loss: 0.0356
#   Step 450 - Loss: 0.0146
#   Step 500 - Loss: 0.0981
#   Step 550 - Loss: 0.0120
#   Step 600 - Loss: 0.0033
#   Step 650 - Loss: 0.0241
#   Step 700 - Loss: 0.0526
#   Step 750 - Loss: 0.0027
#   Step 800 - Loss: 0.1870
#   Step 850 - Loss: 0.0156
#   Step 900 - Loss: 0.0552
#   Step 950 - Loss: 0.0014
#   Step 1000 - Loss: 0.0019
# Train - Loss: 0.0389, Accuracy: 98.76%
# Validation - Loss: 2.0691, Accuracy: 58.39%
#
# Epoch 19/20 시작
#   Step 50 - Loss: 0.0128
#   Step 100 - Loss: 0.0209
#   Step 150 - Loss: 0.0497
#   Step 200 - Loss: 0.0099
#   Step 250 - Loss: 0.0020
#   Step 300 - Loss: 0.0043
#   Step 350 - Loss: 0.0109
#   Step 400 - Loss: 0.0799
#   Step 450 - Loss: 0.0099
#   Step 500 - Loss: 0.0148
#   Step 550 - Loss: 0.0069
#   Step 600 - Loss: 0.0082
#   Step 650 - Loss: 0.0033
#   Step 700 - Loss: 0.0031
#   Step 750 - Loss: 0.0960
#   Step 800 - Loss: 0.3819
#   Step 850 - Loss: 0.0047
#   Step 900 - Loss: 0.0032
#   Step 950 - Loss: 0.0155
#   Step 1000 - Loss: 0.0103
# Train - Loss: 0.0351, Accuracy: 98.98%
# Validation - Loss: 2.0016, Accuracy: 60.13%
#
# Epoch 20/20 시작
#   Step 50 - Loss: 0.0011
#   Step 100 - Loss: 0.0200
#   Step 150 - Loss: 0.0045
#   Step 200 - Loss: 0.0036
#   Step 250 - Loss: 0.1194
#   Step 300 - Loss: 0.0060
#   Step 350 - Loss: 0.0043
#   Step 400 - Loss: 0.0087
#   Step 450 - Loss: 0.0330
#   Step 500 - Loss: 0.0320
#   Step 550 - Loss: 0.0164
#   Step 600 - Loss: 0.0017
#   Step 650 - Loss: 0.0053
#   Step 700 - Loss: 0.0021
#   Step 750 - Loss: 0.2595
#   Step 800 - Loss: 0.0579
#   Step 850 - Loss: 0.0106
#   Step 900 - Loss: 0.0018
#   Step 950 - Loss: 0.0040
#   Step 1000 - Loss: 0.0391
# Train - Loss: 0.0372, Accuracy: 98.93%
# Validation - Loss: 2.0911, Accuracy: 60.05%
# CPU times: user 49min 36s, sys: 1min 42s, total: 51min 18s
# Wall time: 52min 4s

# %%
cam_model_path = os.path.join(os.getenv("HOME"), "work/class_activation_map/cam_model.pt")

torch.save(model, cam_model_path)

# %%
def unnormalize(img_tensor):
    """
    img_tensor: [C, H, W] 텐서 (전처리 상태, 예: normalization 적용됨)
    ImageNet 평균 및 표준편차를 이용하여 복원 (RGB 순서)
    """
    mean = np.array([0.485, 0.456, 0.406])
    std  = np.array([0.229, 0.224, 0.225])
    img = img_tensor.cpu().numpy().transpose(1, 2, 0)
    img = std * img + mean
    img = np.clip(img, 0, 1)
    img = np.uint8(255 * img)
    return img

# %%
image, label, bbox = train_dataset[0]
sample_image = image.unsqueeze(0).to(device)

# %%
cam_model = torch.load(cam_model_path, weights_only=False)

# %%
def generate_cam(model, item):

    model.eval()

    features = []

    def hook(module, input, output):
        features.append(output.detach())

    hook_handle = model.layer4.register_forward_hook(hook)


    output = model(item)

    hook_handle.remove()

    pred_class = output.argmax(dim=1).item()

    fc_weights = model.fc.weight.data.to(item.device)

    fmap = features[0][0]

    cam = torch.zeros(fmap.shape[1:], dtype=torch.float32, device=item.device)

    for i, w in enumerate(fc_weights[pred_class]):
        cam += w * fmap[i, :, :]

    cam = cam.cpu().numpy()

    cam = np.maximum(cam, 0)

    cam = (cam - np.min(cam)) / (np.max(cam) - np.min(cam) + 1e-8)

    return cam

# %%
cam = generate_cam(model, sample_image)

# %%
def visualize_cam(cam):
    plt.imshow(cam, cmap='jet')
    plt.colorbar()
    plt.title("CAM")
    plt.axis('off')
    plt.show()

# %%
visualize_cam(cam)

# %%
def visualize_cam_on_image(cam, img, alpha=0.5):

    cam_resized = cv2.resize(cam, (img.shape[1], img.shape[0]))

    heatmap = cv2.applyColorMap(np.uint8(255 * cam_resized), cv2.COLORMAP_JET)

    heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)

    overlay = heatmap * alpha + img * (1 - alpha)

    overlay = overlay.astype(np.uint8)

    plt.figure(figsize=(8,8))
    plt.imshow(overlay)
    plt.title("CAM Overlay on Image")
    plt.axis('off')
    plt.show()

# %%
def generate_grad_cam(model, activation_layer, item):
    model.eval()

    feature_maps = []
    gradients = []

    def save_feature_map(module, input, output):
        feature_maps.append(output.detach())

    def save_gradient(module, grad_in, grad_out):
        gradients.append(grad_out[0].detach())

    f_handle = activation_layer.register_forward_hook(save_feature_map)
    b_handle = activation_layer.register_full_backward_hook(save_gradient)

    output = model(item)
    target_class = output.argmax(dim=1).item()
    score = output[0, target_class]

    model.zero_grad()
    score.backward()

    f_handle.remove()
    b_handle.remove()

    fmap = feature_maps[0][0]
    grads = gradients[0][0]

    weights = torch.mean(grads, dim=(1,2))

    grad_cam_image = torch.zeros(fmap.shape[1:], dtype=torch.float32, device=fmap.device)
    for i, w in enumerate(weights):
        grad_cam_image += w * fmap[i, :, :]

    grad_cam_image = torch.relu(grad_cam_image)

    grad_cam_image = grad_cam_image.cpu().numpy()

    if grad_cam_image.max() != 0:
        grad_cam_image = (grad_cam_image - grad_cam_image.min()) / (grad_cam_image.max() - grad_cam_image.min() + 1e-8)

    return grad_cam_image

# %%
image, label, ground_bbox = train_dataset[10]

# 1. 대상 레이어 객체를 먼저 변수에 할당합니다.
# 보통 ResNet 계열이라면 model.layer4 또는 model.layer4[-1]을 사용합니다.
target_layer = model.layer4

# 2. 함수 정의에 맞춰 순서대로(model, layer, image) 넣어줍니다.
# 키워드 인자를 쓰고 싶다면 activation_layer=target_layer, item=sample_image 라고 써야 합니다.
grad_cam = generate_grad_cam(model, target_layer, sample_image)

# 시각화 실행
visualize_cam_on_image(grad_cam, orig_img)

# %%
def get_bbox(cam, threshold=0.01):
    coords = np.argwhere(cam > threshold)
    if coords.size == 0:
        return None
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0)
    return (x_min, y_min, x_max, y_max)

# %%
orig_img = unnormalize(image)

# %%
cam_resized = cv2.resize(cam, (orig_img.shape[1], orig_img.shape[0]))
bbox = get_bbox(cam_resized, threshold=0.5)

print(bbox)
# Out:
# (np.int64(71), np.int64(49), np.int64(158), np.int64(134))

# %%
def visualize_bbox_on_image(img, bbox, box_color=(255, 0, 0), thickness=2):
    img_with_bbox = img.copy()
    if bbox is not None:
        x_min, y_min, x_max, y_max = bbox
        cv2.rectangle(img_with_bbox, (x_min, y_min), (x_max, y_max), box_color, thickness)
    else:
        print("활성화된 영역 x")
    return img_with_bbox

# %%
img_bbox = visualize_bbox_on_image(orig_img, bbox)

plt.figure(figsize=(6,6))
plt.imshow(img_bbox)
plt.title("Image with Bounding Box from CAM")
plt.axis("off")
plt.show()

# %%
ground_bbox
# Out:
# [78.848, 19.333333333333332, 169.792, 222.0]

# %%
def get_iou(bbox1, bbox2):
    if bbox1 is None or bbox2 is None:
        return 0.0

    x_min1, y_min1, x_max1, y_max1 = bbox1
    x_min2, y_min2, x_max2, y_max2 = bbox2

    x_min_inter = max(x_min1, x_min2)
    y_min_inter = max(y_min1, y_min2)
    x_max_inter = min(x_max1, x_max2)
    y_max_inter = min(y_max1, y_max2)

    inter_width = max(0, x_max_inter - x_min_inter)
    inter_height = max(0, y_max_inter - y_min_inter)
    inter_area = inter_width * inter_height

    area1 = (x_max1 - x_min1) * (y_max1 - y_min1)
    area2 = (x_max2 - x_min2) * (y_max2 - y_min2)

    union_area = area1 + area2 - inter_area
    if union_area <= 0:
        return 0.0

    iou = inter_area / union_area
    return iou

# %%
get_iou(bbox, ground_bbox)
# Out:
# np.float64(0.3522766796906798)

# %%
def visualize_both_bbox_on_image(img, bbox, ground_truth, thickness=2):
    # 원본 이미지 복사
    img_with_bbox = img.copy()

    x_min, y_min, x_max, y_max = bbox
    cv2.rectangle(img_with_bbox, (x_min, y_min), (x_max, y_max), (255, 0, 0), thickness)

    x_min_t, y_min_t, x_max_t, y_max_t = ground_truth
    cv2.rectangle(img_with_bbox, (x_min_t, y_min_t), (x_max_t, y_max_t), (0, 255, 0), thickness)

    return img_with_bbox

ground_truth = [int(x) for x in ground_bbox]

img_bbox = visualize_both_bbox_on_image(orig_img, bbox, ground_truth)

plt.figure(figsize=(6,6))
plt.imshow(img_bbox)
plt.title("Compare with Ground Truth")
plt.axis("off")
plt.show()

# %%
sample_idx = 11
image, label, ground_bbox = train_dataset[sample_idx]
sample_input = image.unsqueeze(0).to(device)
orig_img = unnormalize(image)

cam_map = generate_cam(model, sample_input)
grad_cam_map = generate_grad_cam(model, model.layer4, sample_input)

cam_resized = cv2.resize(cam_map, (orig_img.shape[1], orig_img.shape[0]))
grad_cam_resized = cv2.resize(grad_cam_map, (orig_img.shape[1], orig_img.shape[0]))

cam_bbox = get_bbox(cam_resized, threshold=0.5)
grad_cam_bbox = get_bbox(grad_cam_resized, threshold=0.5)


iou_cam = get_iou(cam_bbox, ground_bbox)
iou_grad_cam = get_iou(grad_cam_bbox, ground_bbox)

print(f"--- Sample Index: {sample_idx} ---")
print(f"CAM IoU: {iou_cam:.4f}")
print(f"Grad-CAM IoU: {iou_grad_cam:.4f}")


plt.figure(figsize=(15, 7))

plt.subplot(1, 2, 1)
img_cam = visualize_both_bbox_on_image(orig_img, cam_bbox, ground_bbox)
plt.imshow(img_cam)
plt.title(f"CAM (IoU: {iou_cam:.4f})")
plt.axis('off')

plt.subplot(1, 2, 2)
img_grad_cam = visualize_both_bbox_on_image(orig_img, grad_cam_bbox, ground_bbox)
plt.imshow(img_grad_cam)
plt.title(f"Grad-CAM (IoU: {iou_grad_cam:.4f})")
plt.axis('off')

plt.show()
# Out:
# --- Sample Index: 11 ---
# CAM IoU: 0.1618
# Grad-CAM IoU: 0.1618
