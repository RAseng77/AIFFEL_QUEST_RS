# %% [markdown]
# <a href="https://colab.research.google.com/github/RAseng77/AIFFEL_QUEST_RS/blob/master/AIFFEL_QUEST_RS/Exploration%20/Ex02/Exploration2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 인물 사진

# %%
# !pip install opencv-python pixellib
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Collecting pixellib
#   Downloading pixellib-0.7.1-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pixellib) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from pixellib) (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.10.0)
# Collecting imgaug (from pixellib)
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting labelme2coco (from pixellib)
#   Downloading labelme2coco-0.2.6-py3-none-any.whl.metadata (3.5 kB)
# Collecting imantics (from pixellib)
#   Downloading imantics-0.1.12.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.0.12)
# Collecting pyQt5 (from pixellib)
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting fvcore (from pixellib)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath (from pixellib)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from pixellib) (2.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.1.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from pixellib) (3.3.0)
# Collecting yacs (from pixellib)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from pixellib) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pixellib) (4.67.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pixellib) (1.0.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from pixellib) (4.0.1)
# Collecting dataclasses (from pixellib)
#   Downloading dataclasses-0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting hydra-core (from pixellib)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black (from pixellib)
#   Downloading black-26.1.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black->pixellib) (8.3.1)
# Collecting mypy-extensions>=0.4.3 (from black->pixellib)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from black->pixellib) (25.0)
# Collecting pathspec>=1.0.0 (from black->pixellib)
#   Downloading pathspec-1.0.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black->pixellib) (4.5.1)
# Collecting pytokens>=0.3.0 (from black->pixellib)
#   Downloading pytokens-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->pixellib) (6.0.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from iopath->pixellib) (4.15.0)
# Collecting portalocker (from iopath->pixellib)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->pixellib) (4.9.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from imantics->pixellib) (6.0.2)
# Collecting xmljson (from imantics->pixellib)
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (1.16.3)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (2.37.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from imgaug->pixellib) (2.1.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pixellib) (3.6.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pixellib) (2025.12.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pixellib) (0.4)
# Collecting sahi>=0.8.19 (from labelme2coco->pixellib)
#   Downloading sahi-0.11.36-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from labelme2coco->pixellib) (4.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pixellib) (2.9.0.post0)
# Collecting PyQt5-sip<13,>=12.15 (from pyQt5->pixellib)
#   Downloading pyqt5_sip-12.18.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (495 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyQt5->pixellib)
#   Downloading pyqt5_qt5-5.15.18-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.30.0)
# Collecting fire (from sahi>=0.8.19->labelme2coco->pixellib)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pybboxes==0.1.6 (from sahi>=0.8.19->labelme2coco->pixellib)
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.32.4)
# Collecting terminaltables (from sahi>=0.8.19->labelme2coco->pixellib)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.20.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.0.3)
# Downloading pixellib-0.7.1-py3-none-any.whl (430 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.3/430.3 kB 24.0 MB/s eta 0:00:00
# Downloading black-26.1.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 81.5 MB/s eta 0:00:00
# Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.3 MB/s eta 0:00:00
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 60.3 MB/s eta 0:00:00
# Downloading labelme2coco-0.2.6-py3-none-any.whl (19 kB)
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 98.6 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-1.0.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 6.4 MB/s eta 0:00:00
# Downloading pyqt5_qt5-5.15.18-py3-none-manylinux2014_x86_64.whl (60.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 43.7 MB/s eta 0:00:00
# Downloading pyqt5_sip-12.18.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.whl (282 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 27.0 MB/s eta 0:00:00
# Downloading pytokens-0.3.0-py3-none-any.whl (12 kB)
# Downloading sahi-0.11.36-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 12.0 MB/s eta 0:00:00
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 42.5 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 13.2 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fvcore, iopath, imantics
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=e8b70d40d10a0d12ec1b51390f93b589bbacaf76dffbec9d583f824d4bd90f87
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=720298a884ad2626a612c9f393337a2468bcc9e6402598101dc713c8f3be324a
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
#   Building wheel for imantics (setup.py) ... done
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16009 sha256=7b26b2fa19f86fda5a044dac1b5fb315ea895e1462157f778f5c2c3b8d294395
#   Stored in directory: /root/.cache/pip/wheels/40/e1/8d/fd1fa8f30722831661afc8e6efcda609c72d1b73e11f4d49b7
# Successfully built fvcore iopath imantics
# Installing collected packages: xmljson, PyQt5-Qt5, dataclasses, yacs, terminaltables, pytokens, PyQt5-sip, pybboxes, portalocker, pathspec, opencv-python, mypy-extensions, fire, pyQt5, iopath, imantics, hydra-core, black, imgaug, fvcore, sahi, labelme2coco, pixellib
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.12.0.88
#     Uninstalling opencv-python-4.12.0.88:
#       Successfully uninstalled opencv-python-4.12.0.88
# Successfully installed PyQt5-Qt5-5.15.18 PyQt5-sip-12.18.0 black-26.1.0 dataclasses-0.6 fire-0.7.1 fvcore-0.1.5.post20221221 hydra-core-1.3.2 imantics-0.1.12 imgaug-0.4.0 iopath-0.1.10 labelme2coco-0.2.6 mypy-extensions-1.1.0 opencv-python-4.11.0.86 pathspec-1.0.3 pixellib-0.7.1 portalocker-3.2.0 pyQt5-5.15.11 pybboxes-0.1.6 pytokens-0.3.0 sahi-0.11.36 terminaltables-3.1.10 xmljson-0.2.1 yacs-0.1.8

# %%
! mkdir -p /content/human_segmentation/models
! mkdir -p /content/human_segmentation/images

# %%
! ln -s /data/* /content/human_segmentation/images

# %%
import cv2
import os
import numpy as np
import torch
import torchvision.transforms as T
from torchvision.models.segmentation import deeplabv3_resnet101
import matplotlib.pyplot as plt

print("안녕")
# Out:
# 안녕

# %%
home_dir = os.getenv('HOME')
img_path = os.path.join(home_dir, '/content/human_segmentation/images/sung.png')
img_orig = cv2.imread(img_path)

print(f'이미지 크기 : {img_orig.shape}')

plt.imshow(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 이미지 크기 : (1334, 750, 3)

# %%
model = deeplabv3_resnet101(pretrained=True).eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet101_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.Resize((512, 512)),
    T.ToTensor()
])

# %%
input_tensor = transform(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)).unsqueeze(0)

# %%
# %%time

with torch.no_grad():
  output = model(input_tensor)['out'][0]
  output_predictions = output.argmax(0).byte().cpu().numpy()

# 원본 크기로 Resize
output_predictions_resized = cv2.resize(output_predictions, (img_orig.shape[1], img_orig.shape[0]), interpolation=cv2.INTER_NEAREST )
# Out:
# CPU times: user 7.65 s, sys: 377 ms, total: 8.03 s
# Wall time: 1.6 s

# %%
LABEL_NAMES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tv'
]
len(LABEL_NAMES)
# Out:
# 21

# %%
plt.imshow(output_predictions_resized, cmap="jet", alpha=0.7)
plt.title("Sementation Mask")
plt.show()

# %%
unique_classes = np.unique(output_predictions_resized)
unique_classes
# Out:
# array([ 0, 15], dtype=uint8)

# %%
for class_id in unique_classes:
  print(LABEL_NAMES[class_id])
# Out:
# background
# person

# %%
colormap = np.zeros((256, 3), dtype=int)
ind = np.arange(256, dtype=int)

for shift in reversed(range(8)):
  for channel in range(3):
    colormap[:, channel] |= ((ind >> channel) & 1) << shift
  ind >>= 3

colormap[:20]
# Out:
# array([[  0,   0,   0],
#        [128,   0,   0],
#        [  0, 128,   0],
#        [128, 128,   0],
#        [  0,   0, 128],
#        [128,   0, 128],
#        [  0, 128, 128],
#        [128, 128, 128],
#        [ 64,   0,   0],
#        [192,   0,   0],
#        [ 64, 128,   0],
#        [192, 128,   0],
#        [ 64,   0, 128],
#        [192,   0, 128],
#        [ 64, 128, 128],
#        [192, 128, 128],
#        [  0,  64,   0],
#        [128,  64,   0],
#        [  0, 192,   0],
#        [128, 192,   0]])

# %%
colormap[15]
# Out:
# array([192, 128, 128])

# %%
seg_map = (output_predictions_resized == unique_classes[-1])
img_mask = seg_map.astype(np.uint8) * 255
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)

plt.imshow(img_mask, cmap='gray')
plt.show()

# %%
img_show = cv2.addWeighted(img_orig, 0.6, color_mask, 0.4, 0)
plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_orig_blur = cv2.blur(img_orig, (100, 100))

plt.imshow(cv2.cvtColor(img_orig_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_mask_color = cv2.cvtColor(img_mask, cv2.COLOR_GRAY2BGR)

img_bg_mask = cv2.bitwise_not(img_mask_color)

img_bg_blur = cv2.bitwise_and(img_orig_blur, img_bg_mask)
plt.imshow(cv2.cvtColor(img_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_concat = np.where(img_mask_color == 255, img_orig, img_bg_blur)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## -----------------------------------------------------------------

# %% [markdown]
# ## 동물 사진

# %%
cat_path = os.path.join(home_dir, '/content/human_segmentation/images/cat.jpeg')
cat_orig = cv2.imread(cat_path)

plt.imshow(cv2.cvtColor(cat_orig, cv2.COLOR_BGR2RGB))
plt.show()

# %%
input_cat_tensor = transform(cv2.cvtColor(cat_orig, cv2.COLOR_BGR2RGB)).unsqueeze(0)

# %%
with torch.no_grad():
  output_cat = model(input_cat_tensor)['out'][0]
  output_predictions_cat = output_cat.argmax(0).byte().cpu().numpy()

output_predictions_cat_resized = cv2.resize(output_predictions_cat, (cat_orig.shape[1], cat_orig.shape[0]), interpolation=cv2.INTER_NEAREST)

# %%
plt.imshow(output_predictions_cat_resized, cmap="jet", alpha=0.7)
plt.title("Sementation Mask")
plt.show()

# %%
unique_classes = np.unique(output_predictions_cat_resized)
unique_classes
# Out:
# array([ 0,  8, 12], dtype=uint8)

# %% [markdown]
# ## 고양이 사진인데 이 부분에서 강아지로 인식함
# ## 이유가 뭘까?

# %%
for class_id in unique_classes:
  print(LABEL_NAMES[class_id])
# Out:
# background
# cat
# dog

# %% [markdown]
# ## 강아지로 인식한 부분

# %%
seg_map_cat = (output_predictions_cat_resized == unique_classes[-1])
img_mask = seg_map_cat.astype(np.uint8) * 255
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)

plt.imshow(img_mask, cmap='gray')
plt.show()

# %% [markdown]
# ## 정상적인 고양이로 인식한 부분

# %%
seg_map_cat = (output_predictions_cat_resized == unique_classes[-2])
img_mask = seg_map_cat.astype(np.uint8) * 255
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)

plt.imshow(img_mask, cmap='gray')
plt.show()

# %% [markdown]
# ## Sol) transform 부분에 정규화를 사용해보자

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.Resize((512, 512)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
input_cat_tensor = transform(cv2.cvtColor(cat_orig, cv2.COLOR_BGR2RGB)).unsqueeze(0)

with torch.no_grad():
  output_cat = model(input_cat_tensor)['out'][0]
  output_predictions_cat = output_cat.argmax(0).byte().cpu().numpy()

output_predictions_cat_resized = cv2.resize(output_predictions_cat, (cat_orig.shape[1], cat_orig.shape[0]), interpolation=cv2.INTER_NEAREST)

plt.imshow(output_predictions_cat_resized, cmap="jet", alpha=0.7)
plt.title("Sementation Mask")
plt.show()

# %%
unique_classes = np.unique(output_predictions_cat_resized)
unique_classes
# Out:
# array([ 0,  8, 12], dtype=uint8)

# %% [markdown]
# ## 음 그만 알아보자

# %%
img_show_cat = cv2.addWeighted(cat_orig, 0.6, color_mask, 0.4, 0)

plt.imshow(cv2.cvtColor(img_show_cat, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_orig_blur_cat = cv2.blur(cat_orig, (10, 10))

img_mask_color = cv2.cvtColor(img_mask, cv2.COLOR_GRAY2BGR)

img_bg_mask = cv2.bitwise_not(img_mask_color)

img_bg_blur = cv2.bitwise_and(img_orig_blur_cat, img_bg_mask)
plt.imshow(cv2.cvtColor(img_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_concat = np.where(img_mask_color == 255, cat_orig, img_bg_blur)

plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## 배경전환 크로마키사진

# %%
dog_img_path = "/content/human_segmentation/images/dog.jpeg"
back_img_path = "/content/human_segmentation/images/background.jpg"

dog_img = cv2.imread(dog_img_path)
back_img = cv2.imread(back_img_path)

dog_img = cv2.cvtColor(dog_img, cv2.COLOR_BGR2RGB)
back_img = cv2.cvtColor(back_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(dog_img)

plt.subplot(1, 2, 2)
plt.imshow(back_img)

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.Resize((520, 520)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

input_tensor_dog = transform(dog_img).unsqueeze(0)

with torch.no_grad():
  output_1 = model(input_tensor_dog)['out'][0]
  output_predictions_dog = output_1.argmax(0).byte().cpu().numpy()

print(f'추론 마스크 크기 (Before Resize): {output_predictions_dog.shape}')
# Out:
# 추론 마스크 크기 (Before Resize): (520, 520)

# %%
output_predictions_dog_resized = cv2.resize(output_predictions_dog, (dog_img.shape[1], dog_img.shape[0]), interpolation=cv2.INTER_NEAREST)
print(f'추론 마스크 크기 (After Resize): {output_predictions_dog_resized.shape}')
# Out:
# 추론 마스크 크기 (After Resize): (1608, 1206)

# %%
unique_classes_dog = np.unique(output_predictions_dog_resized)
print(f'예측된 클래스 ID: {unique_classes_dog}')
# Out:
# 예측된 클래스 ID: [ 0  9 12]

# %%
target_class_id = unique_classes_dog[-1]

seg_map_dog = (output_predictions_dog_resized == target_class_id)
img_mask = seg_map_dog.astype(np.uint8) * 255

plt.imshow(img_mask, cmap='gray')
plt.show()

# %%
back_img_resized = cv2.resize(back_img, (dog_img.shape[1], dog_img.shape[0]))

img_mask_color = cv2.cvtColor(img_mask, cv2.COLOR_GRAY2BGR)
result_img = np.where(img_mask_color == 255, dog_img, back_img_resized)

plt.imshow(result_img)
plt.show()

# %% [markdown]
# ## 회고

# %% [markdown]
# ## 1. 인물사진 같은 경우 별 문제가 없었으나 동물 사진은 고양이 뒷다리 부분이 강아지로 인식되는 현상이 발생 그래서 솔루션으로 Normalize를 적용해 보았으나 오히려 강아지 뒷다리 인식 면적이 더 넓어짐

# %% [markdown]
# ## 2. 배경전환 크로마키 같은 경우는 오히려 Normalize를 적용하면 의자와 강아지를 인식 잘했지만, Normalize를 적용하지 않을 경우 강아지와 의자를 인식하지 못함
